# %%
import sys
import os

# Agregar la ruta al directorio superior para acceder a "scripts"
sys.path.append(os.path.abspath(".."))

# Importar las librerías necesarias
from sqlalchemy import create_engine, Table, Column, Integer, String, DateTime, MetaData
from datetime import datetime
from scripts.pdf_reader import extraer_datos_pdf

# Configurar la conexión a la base de datos
DATABASE_URL = "postgresql+psycopg2://postgres:Alex5003+-@localhost:5432/prueba_tecnica"
engine = create_engine(DATABASE_URL)

# Definir la estructura de la tabla en la base de datos
metadata = MetaData()
helicobacter_tests = Table('helicobacter_tests', metadata,
    Column('id', Integer, primary_key=True),
    Column('nombre_proveedor', String, nullable=False),
    Column('nombre_paciente', String, nullable=False),
    Column('fecha_emision', DateTime, nullable=False),
    Column('resultado', String, nullable=False),
    Column('fecha_lectura', DateTime, default=datetime.utcnow)
)

# Crear la tabla en la base de datos si no existe
metadata.create_all(engine)
print("Tabla 'helicobacter_tests' creada exitosamente.")
# Out:
# Tabla 'helicobacter_tests' creada exitosamente.

# %%
# Función para leer y extraer datos del PDF (desde scripts/pdf_reader.py)
from scripts.pdf_reader import extraer_datos_pdf

# Función para insertar datos en la base de datos (desde scripts/data_inserter.py)
from scripts.data_inserter import insertar_datos_bd

# %%
import sys
import os

# Agregar la ruta al directorio superior para acceder a "scripts"
sys.path.append(os.path.abspath(".."))

# Importar las funciones desde los scripts
from scripts.pdf_reader import extraer_datos_pdf
from scripts.data_inserter import insertar_datos_bd

# Ruta del archivo PDF de prueba
ruta_pdf = "../data/502-4530635-0-COM3-1.pdf"

# Extraer los datos del PDF
datos = extraer_datos_pdf(ruta_pdf)
print("Datos extraídos del PDF:", datos)
# Out:
# Datos extraídos del PDF: {'nombre_proveedor': 'Blue Medical', 'nombre_paciente': 'CLAUDIA JANETH MACZ HERNANDEZ', 'fecha_emision': datetime.datetime(2024, 2, 24, 0, 0), 'resultado': 'POSITIVO', 'fecha_lectura': datetime.datetime(2024, 10, 31, 16, 14, 0, 387496)}

# %%
import sys
import os

# Agregar la ruta al directorio superior para acceder a "scripts"
sys.path.append(os.path.abspath(".."))

from scripts.inspeccionar_pdf import inspeccionar_pdf

# Ruta del archivo PDF de prueba
ruta_pdf = "../data/502-4421980-1-AMP-1.pdf"

# Ejecutar la inspección para ver el contenido del PDF
inspeccionar_pdf(ruta_pdf)
# Out:
# --- Página 1 ---
# Centro De Diagnostico Centro Medico Las Americas
# Avenida Las Americas 8-42 Zona 13 Edificio Las Americas 10 Local
# 109 Guatemala, Guatemala
# Pbx: (502) 2279-4949 / 2319-4600
# Telefono: 2319-4600  Ext:
# Orden:
# 12639206
# Admision:
# 8- 2299     Habitación:  .
# Paciente:
# Horacio Enrique Albin Izuibejeros
# Edad:
# 54 años     Sexo: M
# Médico:
# 999   Medico Tratante
# Dirección:
# 0
# Teléfono:
# 0
# Fecha orden:
# 08/02/2024 07:21
# Código de validación: 1e9f17f3
# Fecha impresión: 08/02/2024 14:14
# CONTIENE INFORMACIÓN MÉDICA Y SU INTERPRETRACIÓN REQUIERE CONOCIMIENTOS MÉDICOS
# EXAMEN
# RESULTADO
# MEDIDA
# VALOR NORMAL
# Fecha muestra: 08/02/2024 07:21
# HEMATOLOGIA COMPLETA
# REC. GLOBULOS ROJOS:
# 5.09
# MILL/uL
# 4.5 - 5.9
# HEMOGLOBINA:
# 16.0
# g/dl
# 14.0- 17.5
# HEMATOCRITO:
# 48.4
# %
# 40 - 52
# REC. GLOBULOS BLANCOS:
# 4.3
# mil/uL
# 4.4 - 11.3
# EOSINOFILOS:
# 3
# %
# 0.5 - 4
# BASOFILOS:
# 0
# %
# 0 - 1.0
# SEGMENTADOS:
# 59
# %
# ...

# %%
# Verificar que los datos fueron insertados correctamente
with engine.connect() as conn:
    resultado = conn.execute(helicobacter_tests.select())
    for fila in resultado:
        print(fila)

# %% [markdown]
# ## Conclusión
#
# En este notebook, hemos leído archivos PDF de pruebas de Helicobacter Pylori, extraído información relevante y almacenado los resultados en una base de datos PostgreSQL. Este flujo es modular y puede reutilizarse para procesar múltiples archivos de manera eficiente.
#
# ### Próximos Pasos
#
# - Ajustar la función `extraer_datos_pdf` según el formato de otros archivos PDF.
# - Automatizar el procesamiento para varios archivos PDF en un solo paso.

# %% [markdown]
# # Análisis de Pruebas de Helicobacter Pylori
#
# Este notebook está diseñado para extraer datos específicos de archivos PDF de pruebas de Helicobacter Pylori y almacenarlos en una base de datos PostgreSQL. Los datos a extraer incluyen:
# - Nombre del proveedor
# - Nombre del paciente
# - Fecha de emisión del estudio
# - Resultado del estudio (POSITIVO o NEGATIVO)
# - Fecha y hora de lectura (momento en que se lee el archivo)
